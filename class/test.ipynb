# %%
import tensorflow as tf
(x_train, y_train), _ = tf.keras.datasets.cifar10.load_data()

# Use the last 5k training examples as a validation set
x_val1, y_val1 = x_train[45000:50000], y_train[45000:50000]

# %%
tmp = list()
for i in range(len(y_val1)):
  tmp.append(list(y_val1)[i][0])

# %%
y_val1
for i in range(10):
  print(tmp.count(i))
# Out:
# 493
# 488
# 479
# 519
# 475
# 529
# 488
# 485
# 532
# 512

# %%
x_client1, y_client1 = x_train[0:20000], y_train[0:20000]
x_client2, y_client2 = x_train[20000:40000], y_train[20000:40000]

# %%
tmp = list()
for i in range(len(y_client1)):
  tmp.append(list(y_client1)[i][0])

# %%
for i in range(10):
  print(tmp.count(i))
# Out:
# 1989
# 1981
# 2042
# 2011
# 2009
# 1925
# 2038
# 2027
# 2012
# 1966

# %%
tmp = list()
for i in range(len(y_client2)):
  tmp.append(list(y_client2)[i][0])

# %%
for i in range(10):
  print(tmp.count(i))
# Out:
# 1997
# 2005
# 2006
# 1973
# 1994
# 2050
# 1982
# 1996
# 1985
# 2012

# %%
x_client1_test, y_client1_test = x_train[40000:42500], y_train[40000:42500]
x_client2_test, y_client2_test = x_train[42500:45000], y_train[42500:45000]

# %%
tmp = list()
for i in range(len(y_client1_test)):
  tmp.append(list(y_client1_test)[i][0])
for i in range(10):
  print(tmp.count(i))
# Out:
# 253
# 265
# 237
# 244
# 268
# 226
# 242
# 246
# 253
# 266

# %%
tmp = list()
for i in range(len(y_client2_test)):
  tmp.append(list(y_client2_test)[i][0])
for i in range(10):
  print(tmp.count(i))
# Out:
# 268
# 261
# 236
# 253
# 254
# 270
# 250
# 246
# 218
# 244
